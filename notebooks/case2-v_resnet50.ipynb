# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/dl/dl-model-extraction'

# %%
from attacker.query import *
from attacker.utils import *
from victim.__init__ import *

set_seed(42)

# %% [markdown]
# # Query victim model & Train attacker model

# %%
# get dataset in dataloader
trainloader, testloader, outputs = get_dataloader(config["victim"]["data"])
# initialize attacker model
model = get_model(config["attacker"], outputs)
# train attacker model
_ = training(model, trainloader, testloader)

save_visualize(None, _,'title' )

# %%
# get dataset in dataloader
trainloader, testloader, outputs = get_dataloader(config["victim"]["data"])

# query & save test data
querytestloader = query_victim(config["victim"], outputs, testloader, len(testloader.dataset), train=False)

# query train data
querytrainloader = query_victim(config["victim"], outputs, trainloader, config["query_size"], q_type=config["query_type"])

# initialize attacker model
attacker = get_model(config["attacker"], outputs)

# train attacker model
attacker_result = training(attacker, querytrainloader, querytestloader)

# save & visualize model inference
title = f'Trial-A_{config["attacker"]}_{config["victim"]["model_name"]}_{config["victim"]["data"]}{config["query_type"]}_{config["query_size"]}'
percent = save_visualize(attacker, attacker_result,title )
results_dict={"Victim":config["victim"]["model_name"],
                "Dataset":config["victim"]["data"],
                "QueryType": config["query_type"],
                "QuerySize": config["query_size"],
                "Queried Output": 'Labels',
                "Attacker": config["attacker"],
                "Train Loss": percent[0],
                "Train Accuracy": percent[1],
                "Test Loss": percent[2],
                "Test Accuracy": percent[3]}
print(results_dict)

# %% [markdown]
# # Parameters

# %% [raw]
# Case 1: Corseset vs Random ,
#     Attacker - Resnet34
#     Victim - Resnet50
#     klogits - 0
#     Datasest - Cifar10, Cifar100
#     QueryType - Random, Coreset
#     Query Size - 10k, 20k, 30k, 40k, 50k

# %% [raw]
# parameters = {
#         "query_size": [10000, 20000, 30000, 40000, 50000],
#         "query_type": ['coreset','random'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET34]
# }

# %% [raw]
# parameters = {
#         "query_size": [10000, 20000, 30000, 40000, 50000],
#         "query_type": ['coreset','random'],
#         "victim":[{"data": CIFAR_100, "model_name": RESNET50 }],
#         "attacker":[RESNET34]
# }

# %% [raw]
# # fine tune search for query size selection
# parameters = {
#         "query_size": [15000, 25000],
#         "query_type": ['coreset','random'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET50]
# }

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 10k, 30k, 50k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %%
# aish VM - dan login
parameters = {
        "query_size": [20000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
        "attacker":[RESNET50, VGG19_BN]
}

# %% [raw]
# # dan VM
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET34}],
#         "attacker":[RESNET34, RESNET50, VGG19_BN]
# }

# %% [raw]
# # dan VM
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": VGG19_BN}],
#         "attacker":[RESNET34, RESNET50, VGG19_BN]
# }

# %% [raw]
# Case 3 : K-Logits vs Labels
#     Dataset - Cifar10
#     klogits - 0, 3, 10
#     QueryType - Random
#     Query Size - 10k, 30k, 50k
#     Attacker - Resnet34
#     Victim - Resnet50

# %% [raw]
# Case 4 : Out of distribution Dataset
#     Dataset - ood
#     klogits - 0
#     QueryType - Random
#     Query Size - 10k, 30k, 50k
#     Attacker - Resnet34
#     Victim - Resnet50

# %% [markdown]
# # Investigations

# %%
print(f'config={config}\n\nparameters={parameters}\n')
Results = []
# Iterate through Victim Model & Dataset
for victim in parameters["victim"]:
    print('---------------------------------------------------------------------------')
    # get dataset in dataloader
    trainloader, testloader, outputs = get_dataloader(victim["data"])

    # query test data
    querytestloader = query_victim(victim, outputs, testloader, len(testloader.dataset), train=False)

    # Iterate through Attacker Model
    for attacker_type in parameters["attacker"]:
        # Iterate Through Query Type
        for querytype in parameters["query_type"]:
            # Iterate Through Query Size
            for size in parameters["query_size"]:
                print('-----------------------------------------------------------------------------')
                print(f'-----------------------Dataset: {victim["data"]}----------------------------')
                print(f'--------Victim: {victim["model_name"]} Attacker: {attacker_type}------------')
                print(f'---------------Query Type: {querytype} Query Size: {size}-------------------')

                # query train data
                querytrainloader = query_victim(victim, outputs, trainloader, size, q_type=querytype)

                # initialize attacker model
                attacker = get_model(attacker_type, outputs)

                # train attacker model
                attacker_result = training(attacker, querytrainloader, querytestloader)

                # save & visualize model inference
                title = f'A_{attacker_type}_{victim["model_name"]}_{victim["data"]}_{querytype}_{size}'
                percent = save_visualize(attacker, attacker_result,title )
                results_dict={"Victim":victim["model_name"],
                                "Dataset":victim["data"],
                                "QueryType": querytype,
                                "QuerySize": size,
                                "Queried Output": 'Labels',
                                "Attacker": attacker_type,
                                "Train Loss": percent[0],
                                "Train Accuracy": percent[1],
                                "Test Loss": percent[2],
                                "Test Accuracy": percent[3]}

                print(results_dict)
                Results.append(results_dict)
                print('-----------------------------------------------------------------------------')
# Out:
# config={'batch_size': 500, 'learning_rate': 0.008, 'lr_cycles': 2, 'lr_steps': 1000, 'base_lr': 1e-05, 'max_lr': 0.1, 'query_size': 50000, 'query_type': 'coreset', 'victim': {'data': 'cifar_10', 'model_name': 'resnet50'}, 'attacker': 'resnet34'}
#
# parameters={'query_size': [20000], 'query_type': ['coreset'], 'victim': [{'data': 'cifar_10', 'model_name': 'resnet50', 'batch_size': 256, 'max_epochs': 100, 'num_workers': 8, 'learning_rate': 0.01, 'weight_decay': 0.01}], 'attacker': ['resnet50', 'vgg19_bn']}
#
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Query resnet50 victim on cifar_10 dataset
#     - input:10000 queried:10000
# Sample using None with query size 10000
#     - input:10000 sampled:10000
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: resnet50 Attacker: resnet50------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Query resnet50 victim on cifar_10 dataset
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
# epoch 1
#     - train_acc 0.37485 train_loss 1.95062
#     - test_acc  0.41230 test_loss  1.76260
# epoch 2
#     - train_acc 0.42410 train_loss 2.00922
#     - test_acc  0.53990 test_loss  3.92174
# epoch 64
#     - train_acc 0.96695 train_loss 0.18744
#     - test_acc  0.52240 test_loss  3.14438
# epoch 65
#     - train_acc 0.96675 train_loss 0.11416
#     - test_acc  0.52920 test_loss  2.76049
# epoch 66
#     - train_acc 0.96470 train_loss 0.09081
#     - test_acc  0.53500 test_loss  2.45752
# epoch 67
#     - train_acc 0.97070 train_loss 0.08084
#     - test_acc  0.53290 test_loss  2.91821
# epoch 68
#     - train_acc 0.96560 train_loss 0.13935
#     - test_acc  0.47330 test_loss  3.29533
# epoch 69
#     - train_acc 0.95045 train_loss 0.17009
#     - test_acc  0.53480 test_loss  2.82233
# epoch 70
#     - train_acc 0.92455 train_loss 0.51817
#     - test_acc  0.42370 test_loss  4.69875
# epoch 71
#     - train_acc 0.86055 train_loss 0.54970
#     - test_acc  0.46640 test_loss  3.52742
# epoch 72
#     - train_acc 0.91295 train_loss 0.24876
#     - test_acc  0.54180 test_loss  2.17259
# epoch 73
#     - train_acc 0.94285 train_loss 0.19992
#     - test_acc  0.50650 test_loss  2.30165
# epoch 74
#     - train_acc 0.93720 train_loss 0.15118
#     - test_acc  0.51940 test_loss  2.54127
# epoch 75
#     - train_acc 0.95310 train_loss 0.20646
#     - test_acc  0.49840 test_loss  2.71708
# epoch 76
#     - train_acc 0.94860 train_loss 0.16274
#     - test_acc  0.51690 test_loss  2.97447
# epoch 77
#     - train_acc 0.94935 train_loss 0.19085
#     - test_acc  0.54150 test_loss  2.27567
# epoch 78
#     - train_acc 0.96220 train_loss 0.08468
#     - test_acc  0.52810 test_loss  2.57979
# epoch 79
#     - train_acc 0.96605 train_loss 0.20325
#     - test_acc  0.49980 test_loss  3.55104
# epoch 80
#     - train_acc 0.96130 train_loss 0.10198
#     - test_acc  0.54640 test_loss  2.62568
# epoch 81
#     - train_acc 0.97990 train_loss 0.07684
#     - test_acc  0.53840 test_loss  2.76149
# epoch 82
#     - train_acc 0.98560 train_loss 0.03665
#     - test_acc  0.49770 test_loss  3.36659
# epoch 83
#     - train_acc 0.97395 train_loss 0.07054
#     - test_acc  0.53310 test_loss  2.79180
# epoch 84
#     - train_acc 0.97595 train_loss 0.08185
#     - test_acc  0.55080 test_loss  2.66656
# epoch 85
#     - train_acc 0.98045 train_loss 0.03450
#     - test_acc  0.55310 test_loss  2.75618
# epoch 86
#     - train_acc 0.99350 train_loss 0.02014
#     - test_acc  0.55330 test_loss  3.21944
# epoch 87
#     - train_acc 0.99565 train_loss 0.00689
#     - test_acc  0.55340 test_loss  3.64541
# epoch 88
#     - train_acc 0.96525 train_loss 0.08560
#     - test_acc  0.52310 test_loss  2.92595
# epoch 89
#     - train_acc 0.98535 train_loss 0.03048
#     - test_acc  0.54710 test_loss  3.02187
# epoch 90
#     - train_acc 0.98705 train_loss 0.05112
#     - test_acc  0.55720 test_loss  3.11270
# epoch 91
#     - train_acc 0.99280 train_loss 0.01274
#     - test_acc  0.55760 test_loss  3.19047
# epoch 92
#     - train_acc 0.99705 train_loss 0.00892
#     - test_acc  0.56130 test_loss  3.25090
# epoch 93
#     - train_acc 0.99820 train_loss 0.00506
#     - test_acc  0.55600 test_loss  3.54414
# epoch 94
#     - train_acc 0.98500 train_loss 0.77405
#     - test_acc  0.39040 test_loss  4.17768
# epoch 95
#     - train_acc 0.90765 train_loss 0.09395
#     - test_acc  0.54140 test_loss  2.03493
# epoch 96
#     - train_acc 0.99025 train_loss 0.03680
#     - test_acc  0.56210 test_loss  2.67149
# epoch 97
#     - train_acc 0.99720 train_loss 0.02257
#     - test_acc  0.56320 test_loss  2.83631
# epoch 98
#     - train_acc 0.99875 train_loss 0.01032
#     - test_acc  0.56480 test_loss  2.76795
# epoch 99
#     - train_acc 0.99940 train_loss 0.00374
#     - test_acc  0.56620 test_loss  2.95729
# epoch 100
#     - train_acc 0.99940 train_loss 0.00245
#     - test_acc  0.56700 test_loss  3.06170
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'resnet50', 'Train Loss': 0.0024, 'Train Accuracy': 99.94, 'Test Loss': 3.0617, 'Test Accuracy': 56.7}
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: resnet50 Attacker: vgg19_bn------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Loading queried cifar_10 dataset with resnet50 victim
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
# epoch 1
#     - train_acc 0.33605 train_loss 2.02597
#     - test_acc  0.37840 test_loss  1.89721
# epoch 2
#     - train_acc 0.35580 train_loss 2.01890
#     - test_acc  0.27720 test_loss  2.47440
# epoch 3
#     - train_acc 0.33790 train_loss 1.94490
#     - test_acc  0.37910 test_loss  44.74303
# epoch 4
#     - train_acc 0.37620 train_loss 2.00661
#     - test_acc  0.37910 test_loss  1.87620
# epoch 5
#     - train_acc 0.35470 train_loss 2.06270
#     - test_acc  0.15060 test_loss  87.23563
# epoch 6
#     - train_acc 0.36395 train_loss 6.62736
#     - test_acc  0.16890 test_loss  112.73015
# epoch 7
#     - train_acc 0.36155 train_loss 8.27916
#     - test_acc  0.37910 test_loss  1.91343
# epoch 8
#     - train_acc 0.37300 train_loss 1.86485
#     - test_acc  0.37910 test_loss  1.98183
# epoch 9
#     - train_acc 0.37625 train_loss 1.97244
#     - test_acc  0.37910 test_loss  1.98842
# epoch 10
#     - train_acc 0.37625 train_loss 1.94724
#     - test_acc  0.37910 test_loss  1.95199
# epoch 11
#     - train_acc 0.37625 train_loss 1.95296
#     - test_acc  0.37910 test_loss  1.94215
# epoch 12
#     - train_acc 0.37625 train_loss 1.91908
#     - test_acc  0.37910 test_loss  1.91797
# epoch 13
#     - train_acc 0.37625 train_loss 1.89669
#     - test_acc  0.37910 test_loss  1.96314
# epoch 14
#     - train_acc 0.37625 train_loss 1.89931
#     - test_acc  0.37910 test_loss  1.88108
# epoch 15
#     - train_acc 0.37625 train_loss 1.83723
#     - test_acc  0.37910 test_loss  1.90041
# epoch 16
#     - train_acc 0.37625 train_loss 1.86708
#     - test_acc  0.37910 test_loss  1.88589
# epoch 17
#     - train_acc 0.37625 train_loss 1.90780
#     - test_acc  0.37910 test_loss  1.95534
# epoch 18
#     - train_acc 0.37625 train_loss 1.90402
#     - test_acc  0.37910 test_loss  1.92669
# epoch 19
#     - train_acc 0.37625 train_loss 1.89918
#     - test_acc  0.37910 test_loss  1.93622
# epoch 20
#     - train_acc 0.37625 train_loss 1.98725
#     - test_acc  0.37910 test_loss  1.94252
# epoch 21
#     - train_acc 0.37625 train_loss 1.95390
#     - test_acc  0.37910 test_loss  1.92666
# epoch 22
#     - train_acc 0.37625 train_loss 1.92350
#     - test_acc  0.37910 test_loss  1.86905
# epoch 23
#     - train_acc 0.37625 train_loss 1.95110
#     - test_acc  0.37910 test_loss  1.98170
# epoch 24
#     - train_acc 0.37625 train_loss 1.87911
#     - test_acc  0.37910 test_loss  1.92910
# epoch 25
#     - train_acc 0.37625 train_loss 1.93785
#     - test_acc  0.37910 test_loss  1.93008
# epoch 26
#     - train_acc 0.37625 train_loss 1.92488
#     - test_acc  0.37910 test_loss  1.92211
# epoch 27
#     - train_acc 0.37625 train_loss 1.91977
#     - test_acc  0.37910 test_loss  1.91047
# epoch 28
#     - train_acc 0.37625 train_loss 1.93073
#     - test_acc  0.37910 test_loss  1.90754
# epoch 29
#     - train_acc 0.37625 train_loss 1.87967
#     - test_acc  0.37910 test_loss  1.89877
# epoch 30
#     - train_acc 0.37625 train_loss 1.95959
#     - test_acc  0.37910 test_loss  1.90836
# epoch 31
#     - train_acc 0.37625 train_loss 1.96773
#     - test_acc  0.37910 test_loss  1.93154
# epoch 32
#     - train_acc 0.37625 train_loss 1.95648
#     - test_acc  0.37910 test_loss  1.84718
# epoch 33
#     - train_acc 0.37625 train_loss 1.86921
#     - test_acc  0.37910 test_loss  1.94758
# epoch 34
#     - train_acc 0.37625 train_loss 1.95905
#     - test_acc  0.37910 test_loss  1.93065
# epoch 35
#     - train_acc 0.37625 train_loss 1.94906
#     - test_acc  0.37910 test_loss  1.98805
# epoch 36
#     - train_acc 0.37625 train_loss 1.98307
#     - test_acc  0.37910 test_loss  1.93982
# epoch 37
#     - train_acc 0.37625 train_loss 1.91504
#     - test_acc  0.37910 test_loss  1.84782
# epoch 38
#     - train_acc 0.37625 train_loss 2.00403
#     - test_acc  0.37910 test_loss  1.94936
# epoch 39
#     - train_acc 0.37625 train_loss 1.97036
#     - test_acc  0.37910 test_loss  1.86799
# epoch 40
#     - train_acc 0.37625 train_loss 1.91682
#     - test_acc  0.37910 test_loss  1.87680
# epoch 41
#     - train_acc 0.37625 train_loss 1.97845
#     - test_acc  0.37910 test_loss  1.94674
# epoch 42
#     - train_acc 0.37625 train_loss 1.90499
#     - test_acc  0.37910 test_loss  1.96980
# epoch 43
#     - train_acc 0.37625 train_loss 1.90333
#     - test_acc  0.37910 test_loss  1.93029
# epoch 44
#     - train_acc 0.37625 train_loss 1.89973
#     - test_acc  0.37910 test_loss  1.84088
# epoch 45
#     - train_acc 0.37625 train_loss 1.96026
#     - test_acc  0.37910 test_loss  1.94109
# epoch 46
#     - train_acc 0.37625 train_loss 1.92745
#     - test_acc  0.37910 test_loss  1.90170
# epoch 47
#     - train_acc 0.37625 train_loss 1.95533
#     - test_acc  0.37910 test_loss  2.00145
# epoch 48
#     - train_acc 0.37625 train_loss 1.90438
#     - test_acc  0.37910 test_loss  1.95840
# epoch 49
#     - train_acc 0.37625 train_loss 1.94505
#     - test_acc  0.37910 test_loss  1.95469
# epoch 50
#     - train_acc 0.37625 train_loss 1.89994
#     - test_acc  0.37910 test_loss  1.91679
# epoch 51
#     - train_acc 0.37625 train_loss 1.93233
#     - test_acc  0.37910 test_loss  1.91973
# epoch 52
#     - train_acc 0.37625 train_loss 1.94495
#     - test_acc  0.37910 test_loss  1.93835
# epoch 53
#     - train_acc 0.37625 train_loss 1.92386
#     - test_acc  0.37910 test_loss  1.95714
# epoch 54
#     - train_acc 0.37625 train_loss 1.94138
#     - test_acc  0.37910 test_loss  1.91760
# epoch 55
#     - train_acc 0.37625 train_loss 1.92084
#     - test_acc  0.37910 test_loss  1.94082
# epoch 56
#     - train_acc 0.37625 train_loss 1.89444
#     - test_acc  0.37910 test_loss  1.93119
# epoch 57
#     - train_acc 0.37625 train_loss 1.89986
#     - test_acc  0.37910 test_loss  1.96956
# epoch 58
#     - train_acc 0.37625 train_loss 1.96859
#     - test_acc  0.37910 test_loss  1.93895
# epoch 59
#     - train_acc 0.37625 train_loss 1.94713
#     - test_acc  0.37910 test_loss  1.92660
# epoch 60
#     - train_acc 0.37625 train_loss 1.96747
#     - test_acc  0.37910 test_loss  1.94914
# epoch 61
#     - train_acc 0.37625 train_loss 1.88874
#     - test_acc  0.37910 test_loss  1.91406
# epoch 62
#     - train_acc 0.37625 train_loss 1.96034
#     - test_acc  0.37910 test_loss  1.93924
# epoch 63
#     - train_acc 0.37625 train_loss 1.89435
#     - test_acc  0.37910 test_loss  1.93327
# epoch 64
#     - train_acc 0.37625 train_loss 1.93392
#     - test_acc  0.37910 test_loss  1.89446
# epoch 65
#     - train_acc 0.37625 train_loss 1.97891
#     - test_acc  0.37910 test_loss  1.92123
# epoch 66
#     - train_acc 0.37625 train_loss 2.01941
#     - test_acc  0.37910 test_loss  1.92689
# epoch 67
#     - train_acc 0.37625 train_loss 1.88707
#     - test_acc  0.37910 test_loss  1.90629
# epoch 68
#     - train_acc 0.37625 train_loss 1.94604
#     - test_acc  0.37910 test_loss  1.92969
# epoch 69
#     - train_acc 0.37625 train_loss 1.95269
#     - test_acc  0.37910 test_loss  1.90276
# epoch 70
#     - train_acc 0.37625 train_loss 2.01003
#     - test_acc  0.37910 test_loss  1.94115
# epoch 71
#     - train_acc 0.37625 train_loss 1.88380
#     - test_acc  0.37910 test_loss  2.01892
# epoch 72
#     - train_acc 0.37625 train_loss 2.00937
#     - test_acc  0.37910 test_loss  1.91083
# epoch 73
#     - train_acc 0.37625 train_loss 1.95681
#     - test_acc  0.37910 test_loss  1.97376
# epoch 74
#     - train_acc 0.37625 train_loss 1.92026
#     - test_acc  0.37910 test_loss  1.96385
# epoch 75
#     - train_acc 0.37625 train_loss 1.86609
#     - test_acc  0.37910 test_loss  1.87652
# epoch 76
#     - train_acc 0.37625 train_loss 1.93098
#     - test_acc  0.37910 test_loss  1.94061
# epoch 77
#     - train_acc 0.37625 train_loss 1.91507
#     - test_acc  0.37910 test_loss  1.92059
# epoch 78
#     - train_acc 0.37625 train_loss 1.92504
#     - test_acc  0.37910 test_loss  1.89819
# epoch 79
#     - train_acc 0.37625 train_loss 1.91388
#     - test_acc  0.37910 test_loss  1.91519
# epoch 80
#     - train_acc 0.37625 train_loss 1.96110
#     - test_acc  0.37910 test_loss  1.96102
# epoch 81
#     - train_acc 0.37625 train_loss 1.96030
#     - test_acc  0.37910 test_loss  1.92613
# epoch 82
#     - train_acc 0.37625 train_loss 1.94370
#     - test_acc  0.37910 test_loss  1.86182
# epoch 83
#     - train_acc 0.37625 train_loss 1.94535
#     - test_acc  0.37910 test_loss  1.94928
# epoch 84
#     - train_acc 0.37625 train_loss 1.92540
#     - test_acc  0.37910 test_loss  1.91504
# epoch 85
#     - train_acc 0.37625 train_loss 1.97118
#     - test_acc  0.37910 test_loss  1.91456
# epoch 86
#     - train_acc 0.37625 train_loss 1.98280
#     - test_acc  0.37910 test_loss  1.87753
# epoch 87
#     - train_acc 0.37625 train_loss 1.99154
#     - test_acc  0.37910 test_loss  1.90600
# epoch 88
#     - train_acc 0.37625 train_loss 1.90855
#     - test_acc  0.37910 test_loss  1.95325
# epoch 89
#     - train_acc 0.37625 train_loss 1.88871
#     - test_acc  0.37910 test_loss  1.96854
# epoch 90
#     - train_acc 0.37625 train_loss 1.92781
#     - test_acc  0.37910 test_loss  1.86208
# epoch 91
#     - train_acc 0.37625 train_loss 1.94990
#     - test_acc  0.37910 test_loss  1.94733
# epoch 92
#     - train_acc 0.37625 train_loss 1.93915
#     - test_acc  0.37910 test_loss  1.96566
# epoch 93
#     - train_acc 0.37625 train_loss 1.90485
#     - test_acc  0.37910 test_loss  1.91620
# epoch 94
#     - train_acc 0.37625 train_loss 1.98473
#     - test_acc  0.37910 test_loss  1.96028
# epoch 95
#     - train_acc 0.37625 train_loss 1.93310
#     - test_acc  0.37910 test_loss  1.91456
# epoch 96
#     - train_acc 0.37625 train_loss 1.87862
#     - test_acc  0.37910 test_loss  1.87736
# epoch 97
#     - train_acc 0.37625 train_loss 1.94615
#     - test_acc  0.37910 test_loss  1.92332
# epoch 98
#     - train_acc 0.37625 train_loss 1.94927
#     - test_acc  0.37910 test_loss  2.00093
# epoch 99
#     - train_acc 0.37625 train_loss 1.90350
#     - test_acc  0.37910 test_loss  1.98488
# epoch 100
#     - train_acc 0.37625 train_loss 1.89271
#     - test_acc  0.37910 test_loss  1.94227
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'vgg19_bn', 'Train Loss': 1.8927, 'Train Accuracy': 37.62, 'Test Loss': 1.9423, 'Test Accuracy': 37.91}
# -----------------------------------------------------------------------------

# %%
Results
# Out:
# [{'Victim': 'resnet50',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'resnet50',
#   'Train Loss': 0.0024,
#   'Train Accuracy': 99.94,
#   'Test Loss': 3.0617,
#   'Test Accuracy': 56.7},
#  {'Victim': 'resnet50',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'vgg19_bn',
#   'Train Loss': 1.8927,
#   'Train Accuracy': 37.62,
#   'Test Loss': 1.9423,
#   'Test Accuracy': 37.91}]
