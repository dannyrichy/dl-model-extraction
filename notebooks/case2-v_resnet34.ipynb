# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/another_instance/dl-model-extraction'

# %%
from attacker.query import *
from attacker.utils import *
from victim.__init__ import *

set_seed(42)

# %% [markdown]
# # Query victim model & Train attacker model

# %%
# get dataset in dataloader
trainloader, testloader, outputs = get_dataloader(config["victim"]["data"])
# initialize attacker model
model = get_model(config["attacker"], outputs)
# train attacker model
_ = training(model, trainloader, testloader)

save_visualize(None, _,'title' )

# %%
# get dataset in dataloader
trainloader, testloader, outputs = get_dataloader(config["victim"]["data"])

# query & save test data
querytestloader = query_victim(config["victim"], outputs, testloader, len(testloader.dataset), train=False)

# query train data
querytrainloader = query_victim(config["victim"], outputs, trainloader, config["query_size"], q_type=config["query_type"])

# initialize attacker model
attacker = get_model(config["attacker"], outputs)

# train attacker model
attacker_result = training(attacker, querytrainloader, querytestloader)

# save & visualize model inference
title = f'Trial-A_{config["attacker"]}_{config["victim"]["model_name"]}_{config["victim"]["data"]}{config["query_type"]}_{config["query_size"]}'
percent = save_visualize(attacker, attacker_result,title )
results_dict={"Victim":config["victim"]["model_name"],
                "Dataset":config["victim"]["data"],
                "QueryType": config["query_type"],
                "QuerySize": config["query_size"],
                "Queried Output": 'Labels',
                "Attacker": config["attacker"],
                "Train Loss": percent[0],
                "Train Accuracy": percent[1],
                "Test Loss": percent[2],
                "Test Accuracy": percent[3]}
print(results_dict)

# %% [markdown]
# # Parameters

# %% [raw]
# Case 1: Corseset vs Random ,
#     Attacker - Resnet34
#     Victim - Resnet50
#     klogits - 0
#     Datasest - Cifar10, Cifar100
#     QueryType - Random, Coreset
#     Query Size - 10k, 20k, 30k, 40k, 50k

# %% [raw]
# parameters = {
#         "query_size": [10000, 20000, 30000, 40000, 50000],
#         "query_type": ['coreset','random'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET34]
# }

# %% [raw]
# parameters = {
#         "query_size": [10000, 20000, 30000, 40000, 50000],
#         "query_type": ['coreset','random'],
#         "victim":[{"data": CIFAR_100, "model_name": RESNET50 }],
#         "attacker":[RESNET34]
# }

# %% [raw]
# # fine tune search for query size selection
# parameters = {
#         "query_size": [15000, 25000],
#         "query_type": ['coreset','random'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET50]
# }

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 10k, 30k, 50k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %% [raw]
# # aish VM - dan login
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET50, VGG19_BN]
# }

# %%
# dan VM
parameters = {
        "query_size": [20000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET34}],
        "attacker":[RESNET34, RESNET50, VGG19_BN]
}

# %% [raw]
# # dan VM
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": VGG19_BN}],
#         "attacker":[RESNET34, RESNET50, VGG19_BN]
# }

# %% [raw]
# Case 3 : K-Logits vs Labels
#     Dataset - Cifar10
#     klogits - 0, 3, 10
#     QueryType - Random
#     Query Size - 10k, 30k, 50k
#     Attacker - Resnet34
#     Victim - Resnet50

# %% [raw]
# Case 4 : Out of distribution Dataset
#     Dataset - ood
#     klogits - 0
#     QueryType - Random
#     Query Size - 10k, 30k, 50k
#     Attacker - Resnet34
#     Victim - Resnet50

# %% [markdown]
# # Investigations

# %%
print(f'config={config}\n\nparameters={parameters}\n')
Results = []
# Iterate through Victim Model & Dataset
for victim in parameters["victim"]:
    print('---------------------------------------------------------------------------')
    # get dataset in dataloader
    trainloader, testloader, outputs = get_dataloader(victim["data"])

    # query test data
    querytestloader = query_victim(victim, outputs, testloader, len(testloader.dataset), train=False)

    # Iterate through Attacker Model
    for attacker_type in parameters["attacker"]:
        # Iterate Through Query Type
        for querytype in parameters["query_type"]:
            # Iterate Through Query Size
            for size in parameters["query_size"]:
                print('-----------------------------------------------------------------------------')
                print(f'-----------------------Dataset: {victim["data"]}----------------------------')
                print(f'--------Victim: {victim["model_name"]} Attacker: {attacker_type}------------')
                print(f'---------------Query Type: {querytype} Query Size: {size}-------------------')

                # query train data
                querytrainloader = query_victim(victim, outputs, trainloader, size, q_type=querytype)

                # initialize attacker model
                attacker = get_model(attacker_type, outputs)

                # train attacker model
                attacker_result = training(attacker, querytrainloader, querytestloader)

                # save & visualize model inference
                title = f'A_{attacker_type}_{victim["model_name"]}_{victim["data"]}_{querytype}_{size}'
                percent = save_visualize(attacker, attacker_result,title )
                results_dict={"Victim":victim["model_name"],
                                "Dataset":victim["data"],
                                "QueryType": querytype,
                                "QuerySize": size,
                                "Queried Output": 'Labels',
                                "Attacker": attacker_type,
                                "Train Loss": percent[0],
                                "Train Accuracy": percent[1],
                                "Test Loss": percent[2],
                                "Test Accuracy": percent[3]}

                print(results_dict)
                Results.append(results_dict)
                print('-----------------------------------------------------------------------------')
# Out:
# config={'batch_size': 500, 'learning_rate': 0.008, 'lr_cycles': 2, 'lr_steps': 1000, 'base_lr': 1e-05, 'max_lr': 0.1, 'query_size': 50000, 'query_type': 'coreset', 'victim': {'data': 'cifar_10', 'model_name': 'resnet50'}, 'attacker': 'resnet34'}
#
# parameters={'query_size': [20000], 'query_type': ['coreset'], 'victim': [{'data': 'cifar_10', 'model_name': 'resnet34'}], 'attacker': ['resnet34', 'resnet50', 'vgg19_bn']}
#
# ---------------------------------------------------------------------------
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10
# Files already downloaded and verified
# Query resnet34 victim on cifar_10 dataset
#     - input:10000 queried:10000
# Sample using None with query size 10000
#     - input:10000 sampled:10000
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: resnet34 Attacker: resnet34------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Query resnet34 victim on cifar_10 dataset
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
#     - test_acc  0.59610 test_loss  4.04232
# epoch 90
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59590 test_loss  3.97569
# epoch 91
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59620 test_loss  4.28390
# epoch 92
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59670 test_loss  4.32381
# epoch 93
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59610 test_loss  4.28361
# epoch 94
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59600 test_loss  4.29252
# epoch 95
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59610 test_loss  4.38385
# epoch 96
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59700 test_loss  3.69035
# epoch 97
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59840 test_loss  3.66834
# epoch 98
#     - train_acc 1.00000 train_loss 0.00002
#     - test_acc  0.59420 test_loss  4.56118
# epoch 99
#     - train_acc 1.00000 train_loss 0.00001
#     - test_acc  0.59740 test_loss  4.08295
# epoch 100
#     - train_acc 1.00000 train_loss 0.00000
#     - test_acc  0.59660 test_loss  4.31610
# {'Victim': 'resnet34', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'resnet34', 'Train Loss': 0.0, 'Train Accuracy': 100.0, 'Test Loss': 4.3161, 'Test Accuracy': 59.66}
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: resnet34 Attacker: resnet50------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Loading queried cifar_10 dataset with resnet34 victim
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
# epoch 1
#     - train_acc 0.43710 train_loss 1.51231
#     - test_acc  0.48470 test_loss  1.76762
# epoch 2
#     - train_acc 0.46960 train_loss 2.11250
#     - test_acc  0.27140 test_loss  186.52908
# epoch 3
#     - train_acc 0.49770 train_loss 1.46736
#     - test_acc  0.49910 test_loss  1.57730
# epoch 4
#     - train_acc 0.50885 train_loss 1.38239
#     - test_acc  0.49650 test_loss  3.64177
# epoch 5
#     - train_acc 0.48780 train_loss 1.49541
#     - test_acc  0.48190 test_loss  10.56880
# epoch 6
#     - train_acc 0.49845 train_loss 1.44474
#     - test_acc  0.50560 test_loss  1.45225
# epoch 7
#     - train_acc 0.51965 train_loss 1.38088
#     - test_acc  0.51090 test_loss  1.33533
# epoch 8
#     - train_acc 0.53610 train_loss 1.38350
#     - test_acc  0.52570 test_loss  1.68769
# epoch 9
#     - train_acc 0.54995 train_loss 1.19613
#     - test_acc  0.52200 test_loss  1.38547
# epoch 10
#     - train_acc 0.56525 train_loss 1.25203
#     - test_acc  0.53400 test_loss  1.36298
# epoch 11
#     - train_acc 0.57495 train_loss 1.25346
#     - test_acc  0.54980 test_loss  1.30876
# epoch 12
#     - train_acc 0.59995 train_loss 1.10810
#     - test_acc  0.54710 test_loss  1.21350
# {'Victim': 'resnet34', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'resnet50', 'Train Loss': 0.0, 'Train Accuracy': 100.0, 'Test Loss': 3.4361, 'Test Accuracy': 60.6}
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: resnet34 Attacker: vgg19_bn------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Loading queried cifar_10 dataset with resnet34 victim
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
# epoch 1
#     - train_acc 0.42960 train_loss 1.69496
#     - test_acc  0.48030 test_loss  1.74005
# epoch 2
#     - train_acc 0.46570 train_loss 1.74628
#     - test_acc  0.48030 test_loss  2.07336
# epoch 3
#     - train_acc 0.45430 train_loss 6.14063
#     - test_acc  0.07140 test_loss  189260.03125
# epoch 4
#     - train_acc 0.42215 train_loss 1.71809
#     - test_acc  0.46550 test_loss  5.03541
# epoch 5
#     - train_acc 0.47665 train_loss 1.70397
#     - test_acc  0.48030 test_loss  1.72188
# epoch 6
#     - train_acc 0.47680 train_loss 1.69630
#     - test_acc  0.48030 test_loss  1.77800
# epoch 7
#     - train_acc 0.47680 train_loss 1.65969
#     - test_acc  0.48030 test_loss  1.68687
# epoch 8
#     - train_acc 0.47680 train_loss 1.72085
#     - test_acc  0.48030 test_loss  1.78922
# epoch 9
#     - train_acc 0.47680 train_loss 1.70765
#     - test_acc  0.48030 test_loss  1.74635
# epoch 10
#     - train_acc 0.47680 train_loss 1.66232
#     - test_acc  0.48030 test_loss  1.67988
# epoch 11
#     - train_acc 0.47680 train_loss 1.70951
#     - test_acc  0.48030 test_loss  1.63987
# epoch 12
#     - train_acc 0.47680 train_loss 1.71464
#     - test_acc  0.48030 test_loss  1.74713
# epoch 13
#     - train_acc 0.47665 train_loss 1.70603
#     - test_acc  0.48030 test_loss  1.71884
# epoch 14
#     - train_acc 0.47680 train_loss 1.66647
#     - test_acc  0.48030 test_loss  1.68487
# epoch 15
#     - train_acc 0.46580 train_loss 729.88275
#     - test_acc  0.07140 test_loss  1240420736.00000
# epoch 16
#     - train_acc 0.30460 train_loss 1605.12732
#     - test_acc  0.46460 test_loss  129521.57812
# epoch 17
#     - train_acc 0.44080 train_loss 299.50443
#     - test_acc  0.48030 test_loss  22731.46094
# epoch 18
#     - train_acc 0.46295 train_loss 2157.56104
#     - test_acc  0.48030 test_loss  1.76411
# epoch 19
#     - train_acc 0.34535 train_loss 1971.05249
#     - test_acc  0.47730 test_loss  7392.15527
# epoch 20
#     - train_acc 0.32470 train_loss 1725.65076
#     - test_acc  0.48040 test_loss  1.64239
# epoch 21
#     - train_acc 0.45810 train_loss 55.74568
#     - test_acc  0.48030 test_loss  1.70078
# epoch 22
#     - train_acc 0.47110 train_loss 70.89198
#     - test_acc  0.48030 test_loss  1.69833
# epoch 23
#     - train_acc 0.47315 train_loss 60.33199
#     - test_acc  0.48030 test_loss  1.75936
# epoch 24
#     - train_acc 0.47420 train_loss 5.88665
#     - test_acc  0.48030 test_loss  1.68344
# epoch 25
#     - train_acc 0.47435 train_loss 2.62988
#     - test_acc  0.48030 test_loss  1.66440
# epoch 26
#     - train_acc 0.47455 train_loss 6.06879
#     - test_acc  0.48030 test_loss  1.66995
# epoch 27
#     - train_acc 0.47520 train_loss 12.76145
#     - test_acc  0.48030 test_loss  1.64374
# epoch 28
#     - train_acc 0.47510 train_loss 4.65419
#     - test_acc  0.48030 test_loss  1.70331
# epoch 29
#     - train_acc 0.47540 train_loss 1.73413
#     - test_acc  0.48030 test_loss  1.58389
# epoch 30
#     - train_acc 0.47525 train_loss 5.54519
#     - test_acc  0.48030 test_loss  1.78632
# epoch 31
#     - train_acc 0.47565 train_loss 3.67722
#     - test_acc  0.48030 test_loss  1.58260
# epoch 32
#     - train_acc 0.47540 train_loss 8.02849
#     - test_acc  0.48030 test_loss  1.69369
# epoch 33
#     - train_acc 0.47530 train_loss 1.69648
#     - test_acc  0.48030 test_loss  1.66962
# epoch 34
#     - train_acc 0.47515 train_loss 3.74553
#     - test_acc  0.48030 test_loss  1.65118
# epoch 35
#     - train_acc 0.47565 train_loss 2.22767
#     - test_acc  0.48030 test_loss  1.65075
# epoch 36
#     - train_acc 0.47565 train_loss 1.62410
#     - test_acc  0.48030 test_loss  1.71271
# epoch 37
#     - train_acc 0.47570 train_loss 3.71813
#     - test_acc  0.48030 test_loss  1.61668
# epoch 38
#     - train_acc 0.47610 train_loss 1.67064
#     - test_acc  0.48030 test_loss  1.79420
# epoch 39
#     - train_acc 0.47585 train_loss 2.27335
#     - test_acc  0.48030 test_loss  1.67711
# epoch 40
#     - train_acc 0.47615 train_loss 4.08209
#     - test_acc  0.48030 test_loss  1.63401
# epoch 41
#     - train_acc 0.47555 train_loss 1.75272
#     - test_acc  0.48030 test_loss  1.66656
# epoch 42
#     - train_acc 0.47610 train_loss 1.72268
#     - test_acc  0.48030 test_loss  1.64234
# epoch 43
#     - train_acc 0.47625 train_loss 1.91525
#     - test_acc  0.48030 test_loss  1.67512
# epoch 44
#     - train_acc 0.47605 train_loss 1.76295
#     - test_acc  0.48030 test_loss  1.68855
# epoch 45
#     - train_acc 0.47615 train_loss 1.74263
#     - test_acc  0.48030 test_loss  1.73136
# epoch 46
#     - train_acc 0.47590 train_loss 1.72104
#     - test_acc  0.48030 test_loss  1.64399
# epoch 47
#     - train_acc 0.47605 train_loss 1.76126
#     - test_acc  0.48030 test_loss  1.62866
# epoch 48
#     - train_acc 0.47610 train_loss 1.73873
#     - test_acc  0.48030 test_loss  1.65258
# epoch 49
#     - train_acc 0.47590 train_loss 1.82075
#     - test_acc  0.48030 test_loss  1.72090
# epoch 50
#     - train_acc 0.47610 train_loss 1.70097
#     - test_acc  0.48030 test_loss  1.67958
# epoch 51
#     - train_acc 0.47600 train_loss 4.08724
#     - test_acc  0.48030 test_loss  1.74319
# epoch 52
#     - train_acc 0.47595 train_loss 1.77668
#     - test_acc  0.48030 test_loss  1.73023
# epoch 53
#     - train_acc 0.47625 train_loss 3.12645
#     - test_acc  0.48030 test_loss  1.60575
# epoch 54
#     - train_acc 0.47605 train_loss 1.73231
#     - test_acc  0.48030 test_loss  1.73516
# epoch 55
#     - train_acc 0.47580 train_loss 3.67733
#     - test_acc  0.48030 test_loss  1.71431
# epoch 56
#     - train_acc 0.47655 train_loss 1.71065
#     - test_acc  0.48030 test_loss  1.66252
# epoch 57
#     - train_acc 0.47615 train_loss 1.66111
#     - test_acc  0.48030 test_loss  1.71315
# epoch 58
#     - train_acc 0.47625 train_loss 1.70126
#     - test_acc  0.48030 test_loss  1.61057
# epoch 59
#     - train_acc 0.47640 train_loss 1.79650
#     - test_acc  0.48030 test_loss  1.74037
# epoch 60
#     - train_acc 0.47585 train_loss 1.63287
#     - test_acc  0.48030 test_loss  1.63309
# epoch 61
#     - train_acc 0.47640 train_loss 1.79230
#     - test_acc  0.48030 test_loss  1.72575
# epoch 62
#     - train_acc 0.47595 train_loss 1.87078
#     - test_acc  0.48030 test_loss  1.75724
# epoch 63
#     - train_acc 0.47605 train_loss 2.96787
#     - test_acc  0.48030 test_loss  1.76095
# epoch 64
#     - train_acc 0.47620 train_loss 1.74858
#     - test_acc  0.48030 test_loss  1.72037
# epoch 65
#     - train_acc 0.47555 train_loss 1.82667
#     - test_acc  0.48030 test_loss  1.67824
# epoch 66
#     - train_acc 0.47625 train_loss 1.81415
#     - test_acc  0.48030 test_loss  1.63830
# epoch 67
#     - train_acc 0.47640 train_loss 1.78429
#     - test_acc  0.48030 test_loss  1.71523
# epoch 68
#     - train_acc 0.47570 train_loss 2.06735
#     - test_acc  0.48030 test_loss  1.73346
# epoch 69
#     - train_acc 0.47600 train_loss 2.01588
#     - test_acc  0.48030 test_loss  1.66798
# epoch 70
#     - train_acc 0.47595 train_loss 2.57636
#     - test_acc  0.48030 test_loss  1.67764
# epoch 71
#     - train_acc 0.47580 train_loss 2.82952
#     - test_acc  0.48030 test_loss  1.64607
# epoch 72
#     - train_acc 0.47535 train_loss 2.98701
#     - test_acc  0.48030 test_loss  1.75190
# epoch 73
#     - train_acc 0.47625 train_loss 6.01781
#     - test_acc  0.48030 test_loss  1.71447
# epoch 74
#     - train_acc 0.47555 train_loss 1.82975
#     - test_acc  0.48030 test_loss  1.68079
# epoch 75
#     - train_acc 0.47525 train_loss 2.90454
#     - test_acc  0.48030 test_loss  1.66140
# epoch 76
#     - train_acc 0.47485 train_loss 14.04670
#     - test_acc  0.48030 test_loss  1.70304
# epoch 77
#     - train_acc 0.47545 train_loss 19.68610
#     - test_acc  0.48030 test_loss  1.66308
# epoch 78
#     - train_acc 0.47600 train_loss 1.91232
#     - test_acc  0.48030 test_loss  1.72574
# epoch 79
#     - train_acc 0.47590 train_loss 1.66292
#     - test_acc  0.48030 test_loss  1.69300
# epoch 80
#     - train_acc 0.47640 train_loss 1.66014
#     - test_acc  0.48030 test_loss  1.68792
# epoch 81
#     - train_acc 0.47580 train_loss 1.67546
#     - test_acc  0.48030 test_loss  1.68158
# epoch 82
#     - train_acc 0.47610 train_loss 3.55727
#     - test_acc  0.48030 test_loss  1.72416
# epoch 83
#     - train_acc 0.47550 train_loss 1.73202
#     - test_acc  0.48030 test_loss  1.66472
# epoch 84
#     - train_acc 0.47595 train_loss 1.77746
#     - test_acc  0.48030 test_loss  1.73337
# epoch 85
#     - train_acc 0.47585 train_loss 1.81632
#     - test_acc  0.48030 test_loss  1.72681
# epoch 86
#     - train_acc 0.47565 train_loss 1.94759
#     - test_acc  0.48030 test_loss  1.65055
# epoch 87
#     - train_acc 0.47625 train_loss 1.76389
#     - test_acc  0.48030 test_loss  1.78989
# epoch 88
#     - train_acc 0.47565 train_loss 1.87206
#     - test_acc  0.48030 test_loss  1.81507
# epoch 89
#     - train_acc 0.47625 train_loss 1.67812
#     - test_acc  0.48030 test_loss  1.66630
# epoch 90
#     - train_acc 0.47590 train_loss 1.74163
#     - test_acc  0.48030 test_loss  1.69986
# epoch 91
#     - train_acc 0.47650 train_loss 2.88002
#     - test_acc  0.48030 test_loss  1.71506
# epoch 92
#     - train_acc 0.47625 train_loss 1.75893
#     - test_acc  0.48030 test_loss  1.73222
# epoch 93
#     - train_acc 0.47610 train_loss 1.65495
#     - test_acc  0.48030 test_loss  1.67480
# epoch 94
#     - train_acc 0.47620 train_loss 1.61262
#     - test_acc  0.48030 test_loss  1.71335
# epoch 95
#     - train_acc 0.47615 train_loss 1.71078
#     - test_acc  0.48030 test_loss  1.75535
# epoch 96
#     - train_acc 0.47650 train_loss 1.68978
#     - test_acc  0.48030 test_loss  1.66869
# epoch 97
#     - train_acc 0.47655 train_loss 1.70525
#     - test_acc  0.48030 test_loss  1.67499
# epoch 98
#     - train_acc 0.47625 train_loss 1.60719
#     - test_acc  0.48030 test_loss  1.69586
# epoch 99
#     - train_acc 0.47640 train_loss 1.64507
#     - test_acc  0.48030 test_loss  1.71512
# epoch 100
#     - train_acc 0.47615 train_loss 1.68450
#     - test_acc  0.48030 test_loss  1.67346
# {'Victim': 'resnet34', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'vgg19_bn', 'Train Loss': 1.6845, 'Train Accuracy': 47.61, 'Test Loss': 1.6735, 'Test Accuracy': 48.03}
# -----------------------------------------------------------------------------

# %%
Results
# Out:
# [{'Victim': 'resnet34',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'resnet34',
#   'Train Loss': 0.0,
#   'Train Accuracy': 100.0,
#   'Test Loss': 4.3161,
#   'Test Accuracy': 59.66},
#  {'Victim': 'resnet34',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'resnet50',
#   'Train Loss': 0.0,
#   'Train Accuracy': 100.0,
#   'Test Loss': 3.4361,
#   'Test Accuracy': 60.6},
#  {'Victim': 'resnet34',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'vgg19_bn',
#   'Train Loss': 1.6845,
#   'Train Accuracy': 47.61,
#   'Test Loss': 1.6735,
#   'Test Accuracy': 48.03}]
