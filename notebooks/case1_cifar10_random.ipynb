# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/kadhi/dl-model-extraction'

# %%
from attacker.training import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Case - 1

# %% [raw]
# Case 1: Corseset vs Random ,
#     Attacker - Resnet34
#     Victim - Resnet50
#     klogits - 0
#     Datasest - Cifar10, Cifar100
#     QueryType - Random, Coreset
#     Query Size - 5k, 10k, 25k, 50k

# %% [raw]
# case1_cifar10 = {
#         "query_size": [5000, 10000, 25000, 50000],
#         "query_type": ['coreset','random'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET34],
#         "k_logits": [None]
# }

# %%
case1_cifar10_random = {
        "query_size": [5000, 10000, 25000, 50000],
        "query_type": ['random'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
        "attacker":[RESNET34],
        "k_logits": [None]
}

# %% [markdown]
# # Investigations

# %% [markdown]
# ## case - 1 to 4

# %%
investigate(case1_cifar10_random, seed=42)
# Out:
# PARAMETERS for investigation:
# {'attacker': ['resnet34'],
#  'k_logits': [None],
#  'query_size': [5000, 10000, 25000, 50000],
#  'query_type': ['random'],
#  'victim': [{'data': 'cifar_10', 'model_name': 'resnet50'}]}
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:10000 queried:10000
# Sampling using None with query size 10000
# 	- input:10000 sampled:10000
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using random with query size 5000
# 	- input:50000 sampled:5000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: random	Query Size: 5000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████| 600/600 [1:01:48<00:00,  6.18s/it]
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'random', 'QuerySize': 5000, 'Queried Logits': None, 'Attacker': 'resnet34', 'Train Loss': 0.0004, 'Train Accuracy': 100.0, 'Test Loss': 2.5725, 'Test Accuracy': 66.84}
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using random with query size 10000
# 	- input:50000 sampled:10000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: random	Query Size: 10000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 300/300 [49:06<00:00,  9.82s/it]
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'random', 'QuerySize': 10000, 'Queried Logits': None, 'Attacker': 'resnet34', 'Train Loss': 0.0005, 'Train Accuracy': 99.92, 'Test Loss': 1.8299, 'Test Accuracy': 73.52}
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using random with query size 25000
# 	- input:50000 sampled:25000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: random	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 120/120 [41:22<00:00, 20.69s/it]
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'random', 'QuerySize': 25000, 'Queried Logits': None, 'Attacker': 'resnet34', 'Train Loss': 0.0903, 'Train Accuracy': 98.41, 'Test Loss': 1.0676, 'Test Accuracy': 80.75}
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using random with query size 50000
# 	- input:50000 sampled:50000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: random	Query Size: 50000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 60/60 [38:53<00:00, 38.89s/it]
# {'Victim': 'resnet50', 'Dataset': 'cifar_10', 'QueryType': 'random', 'QuerySize': 50000, 'Queried Logits': None, 'Attacker': 'resnet34', 'Train Loss': 0.1925, 'Train Accuracy': 93.7, 'Test Loss': 0.555, 'Test Accuracy': 84.92}
# -----------------------------------------------------------------------------
# [{'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 5000,
#   'QueryType': 'random',
#   'Test Accuracy': 66.84,
#   'Test Loss': 2.5725,
#   'Train Accuracy': 100.0,
#   'Train Loss': 0.0004,
#   'Victim': 'resnet50'},
#  {'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 10000,
#   'QueryType': 'random',
#   'Test Accuracy': 73.52,
#   'Test Loss': 1.8299,
#   'Train Accuracy': 99.92,
#   'Train Loss': 0.0005,
#   'Victim': 'resnet50'},
#  {'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'random',
#   'Test Accuracy': 80.75,
#   'Test Loss': 1.0676,
#   'Train Accuracy': 98.41,
#   'Train Loss': 0.0903,
#   'Victim': 'resnet50'},
#  {'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 50000,
#   'QueryType': 'random',
#   'Test Accuracy': 84.92,
#   'Test Loss': 0.555,
#   'Train Accuracy': 93.7,
#   'Train Loss': 0.1925,
#   'Victim': 'resnet50'}]

# %% [raw]
# investigate(config["base"], seed=42) #to run default config
