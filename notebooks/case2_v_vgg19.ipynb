# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/dl-model-extraction'

# %%
from attacker.training import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Case - 2

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 25k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %%
case2_v_vgg19 = {
        "query_size": [25000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": VGG19_BN}],
        "attacker":[RESNET34, RESNET50, VGG19_BN],
        "k_logits": [None]
}

# %% [markdown]
# # Investigations

# %% [markdown]
# ## case - 2

# %%
investigate(case2_v_vgg19, seed=42)
# Out:
# PARAMETERS for investigation:
# {'attacker': ['resnet34', 'resnet50', 'vgg19_bn'],
#  'k_logits': [None],
#  'query_size': [25000],
#  'query_type': ['coreset'],
#  'victim': [{'data': 'cifar_10', 'model_name': 'vgg19_bn'}]}
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Querying vgg19_bn victim on cifar_10 dataset
# 	- input:10000 queried:10000 -victim acc: 0.9394999742507935
# Sampling using None with query size 10000
# 	- input:10000 sampled:10000
# Querying vgg19_bn victim on cifar_10 dataset
# 	- input:50000 queried:50000 -victim acc: 0.9991799592971802
# Sampling using coreset with query size 25000
# 	- input:50000 sampled:25000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: vgg19_bn	Attacker: resnet34
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 80/80 [28:15<00:00, 21.19s/it]
# {'Attacker': 'resnet34',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 81.34,
#  'Test Loss': 0.8204,
#  'Train Accuracy': 95.93,
#  'Train Loss': 0.0813,
#  'Victim': 'vgg19_bn'}
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: vgg19_bn	Attacker: resnet50
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 80/80 [33:15<00:00, 24.94s/it]
# {'Attacker': 'resnet50',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 77.0,
#  'Test Loss': 0.6354,
#  'Train Accuracy': 82.14,
#  'Train Loss': 0.45,
#  'Victim': 'vgg19_bn'}
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: vgg19_bn	Attacker: vgg19_bn
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 80/80 [1:06:53<00:00, 50.17s/it]
# {'Attacker': 'vgg19_bn',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 9.86,
#  'Test Loss': 2.3019,
#  'Train Accuracy': 10.2,
#  'Train Loss': 2.3035,
#  'Victim': 'vgg19_bn'}
# -----------------------------------------------------------------------------
# [{'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 81.34,
#   'Test Loss': 0.8204,
#   'Train Accuracy': 95.93,
#   'Train Loss': 0.0813,
#   'Victim': 'vgg19_bn'},
#  {'Attacker': 'resnet50',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 77.0,
#   'Test Loss': 0.6354,
#   'Train Accuracy': 82.14,
#   'Train Loss': 0.45,
#   'Victim': 'vgg19_bn'},
#  {'Attacker': 'vgg19_bn',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 9.86,
#   'Test Loss': 2.3019,
#   'Train Accuracy': 10.2,
#   'Train Loss': 2.3035,
#   'Victim': 'vgg19_bn'}]

# %% [raw]
# investigate(config["base"], seed=42) #to run default config
