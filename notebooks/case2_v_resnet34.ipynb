# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/kadhi/dl-model-extraction'

# %%
from attacker.training import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Case - 2

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 25k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %%
case2_v_resnet34 = {
        "query_size": [25000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET34}],
        "attacker":[RESNET34, RESNET50, VGG19_BN],
        "k_logits": [None]
}

# %% [markdown]
# # Investigations

# %% [markdown]
# ## case - 2

# %%
investigate(case2_v_resnet34, seed=42)
# Out:
# PARAMETERS for investigation:
# {'attacker': ['resnet34', 'resnet50', 'vgg19_bn'],
#  'k_logits': [None],
#  'query_size': [25000],
#  'query_type': ['coreset'],
#  'victim': [{'data': 'cifar_10', 'model_name': 'resnet34'}]}
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Querying resnet34 victim on cifar_10 dataset
# 	- input:10000 queried:10000 -victim acc: 0.9332999587059021
# Sampling using None with query size 10000
# 	- input:10000 sampled:10000
# Querying resnet34 victim on cifar_10 dataset
# 	- input:50000 queried:50000 -victim acc: 0.9989799857139587
# Sampling using coreset with query size 25000
# 	- input:50000 sampled:25000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet34	Attacker: resnet34
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 80/80 [27:39<00:00, 20.74s/it]
# {'Attacker': 'resnet34',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 80.27,
#  'Test Loss': 0.8619,
#  'Train Accuracy': 95.75,
#  'Train Loss': 0.0683,
#  'Victim': 'resnet34'}
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet34	Attacker: resnet50
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 80/80 [32:40<00:00, 24.51s/it]
# {'Attacker': 'resnet50',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 79.38,
#  'Test Loss': 0.6336,
#  'Train Accuracy': 86.83,
#  'Train Loss': 0.3011,
#  'Victim': 'resnet34'}
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet34	Attacker: vgg19_bn
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 80/80 [1:05:44<00:00, 49.31s/it]
# {'Attacker': 'vgg19_bn',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 10.11,
#  'Test Loss': 2.3018,
#  'Train Accuracy': 10.2,
#  'Train Loss': 2.3034,
#  'Victim': 'resnet34'}
# -----------------------------------------------------------------------------
# [{'Attacker': 'resnet34',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 80.27,
#   'Test Loss': 0.8619,
#   'Train Accuracy': 95.75,
#   'Train Loss': 0.0683,
#   'Victim': 'resnet34'},
#  {'Attacker': 'resnet50',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 79.38,
#   'Test Loss': 0.6336,
#   'Train Accuracy': 86.83,
#   'Train Loss': 0.3011,
#   'Victim': 'resnet34'},
#  {'Attacker': 'vgg19_bn',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 10.11,
#   'Test Loss': 2.3018,
#   'Train Accuracy': 10.2,
#   'Train Loss': 2.3034,
#   'Victim': 'resnet34'}]

# %% [raw]
# investigate(config["base"], seed=42) #to run default config
