# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/dl-model-extraction'

# %%
from attacker.query import *
from attacker.utils import *
from victim.__init__ import *

set_seed(42)

# %% [markdown]
# # Parameters

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 10k, 30k, 50k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %% [raw]
# # aish VM - dan login
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
#         "attacker":[RESNET50, VGG19_BN]
# }

# %% [raw]
# # dan VM
# parameters = {
#         "query_size": [20000],
#         "query_type": ['coreset'],
#         "victim":[{ "data": CIFAR_10, "model_name": RESNET34}],
#         "attacker":[RESNET34, RESNET50, VGG19_BN]
# }

# %%
# dan VM
parameters = {
        "query_size": [20000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": VGG19_BN}],
        "attacker":[VGG19_BN]
}

# %% [markdown]
# # Investigations

# %%
print(f'config={config}\n\nparameters={parameters}\n')
Results = []
# Iterate through Victim Model & Dataset
for victim in parameters["victim"]:
    print('---------------------------------------------------------------------------')
    # get dataset in dataloader
    trainloader, testloader, outputs = get_dataloader(victim["data"])

    # query test data
    querytestloader = query_victim(victim, outputs, testloader, len(testloader.dataset), train=False)

    # Iterate through Attacker Model
    for attacker_type in parameters["attacker"]:
        # Iterate Through Query Type
        for querytype in parameters["query_type"]:
            # Iterate Through Query Size
            for size in parameters["query_size"]:
                print('-----------------------------------------------------------------------------')
                print(f'-----------------------Dataset: {victim["data"]}----------------------------')
                print(f'--------Victim: {victim["model_name"]} Attacker: {attacker_type}------------')
                print(f'---------------Query Type: {querytype} Query Size: {size}-------------------')

                # query train data
                querytrainloader = query_victim(victim, outputs, trainloader, size, q_type=querytype)

                # initialize attacker model
                attacker = get_model(attacker_type, outputs)

                # train attacker model
                attacker_result = training(attacker, querytrainloader, querytestloader)

                # save & visualize model inference
                title = f'A_{attacker_type}_{victim["model_name"]}_{victim["data"]}_{querytype}_{size}'
                percent = save_visualize(attacker, attacker_result,title )
                results_dict={"Victim":victim["model_name"],
                                "Dataset":victim["data"],
                                "QueryType": querytype,
                                "QuerySize": size,
                                "Queried Output": 'Labels',
                                "Attacker": attacker_type,
                                "Train Loss": percent[0],
                                "Train Accuracy": percent[1],
                                "Test Loss": percent[2],
                                "Test Accuracy": percent[3]}

                print(results_dict)
                Results.append(results_dict)
                print('-----------------------------------------------------------------------------')
# Out:
# config={'batch_size': 500, 'learning_rate': 0.008, 'lr_cycles': 2, 'lr_steps': 1000, 'base_lr': 1e-05, 'max_lr': 0.1, 'query_size': 50000, 'query_type': 'coreset', 'victim': {'data': 'cifar_10', 'model_name': 'resnet50'}, 'attacker': 'resnet34'}
#
# parameters={'query_size': [20000], 'query_type': ['coreset'], 'victim': [{'data': 'cifar_10', 'model_name': 'vgg19_bn'}], 'attacker': ['vgg19_bn']}
#
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Loading queried cifar_10 dataset with vgg19_bn victim
#     - input:10000 queried:10000
# Sample using None with query size 10000
#     - input:10000 sampled:10000
# -----------------------------------------------------------------------------
# -----------------------Dataset: cifar_10----------------------------
# --------Victim: vgg19_bn Attacker: vgg19_bn------------
# ---------------Query Type: coreset Query Size: 20000-------------------
# Loading queried cifar_10 dataset with vgg19_bn victim
#     - input:50000 queried:50000
# Sample using coreset with query size 20000
#     - input:50000 sampled:20000
# Total epochs: 100
# epoch 1
#     - train_acc 0.41440 train_loss 2.05375
#     - test_acc  0.45080 test_loss  2.07709
# epoch 2
#     - train_acc 0.44600 train_loss 1.85252
#     - test_acc  0.45030 test_loss  1.85963
# epoch 3
#     - train_acc 0.44665 train_loss 1.85056
#     - test_acc  0.45080 test_loss  1.79468
# epoch 4
#     - train_acc 0.41660 train_loss 3.52860
#     - test_acc  0.29450 test_loss  176.51027
# epoch 5
#     - train_acc 0.44900 train_loss 1.86759
#     - test_acc  0.45080 test_loss  1.83808
# epoch 6
#     - train_acc 0.44750 train_loss 1.87487
#     - test_acc  0.45110 test_loss  1.87507
# epoch 7
#     - train_acc 0.44725 train_loss 1.76984
#     - test_acc  0.45080 test_loss  1.90955
# epoch 8
#     - train_acc 0.44710 train_loss 1.79592
#     - test_acc  0.45080 test_loss  1.79579
# epoch 9
#     - train_acc 0.44710 train_loss 1.86947
#     - test_acc  0.45080 test_loss  1.75417
# epoch 10
#     - train_acc 0.44710 train_loss 1.89919
#     - test_acc  0.45080 test_loss  1.87354
# epoch 11
#     - train_acc 0.44710 train_loss 1.83353
#     - test_acc  0.45080 test_loss  1.84909
# epoch 12
#     - train_acc 0.44710 train_loss 1.85168
#     - test_acc  0.45080 test_loss  1.88080
# epoch 13
#     - train_acc 0.44710 train_loss 1.81451
#     - test_acc  0.45080 test_loss  1.84866
# epoch 14
#     - train_acc 0.44710 train_loss 1.86721
#     - test_acc  0.45080 test_loss  1.78782
# epoch 15
#     - train_acc 0.44710 train_loss 1.85135
#     - test_acc  0.45080 test_loss  1.80045
# epoch 16
#     - train_acc 0.44710 train_loss 1.82808
#     - test_acc  0.45080 test_loss  1.75875
# epoch 17
#     - train_acc 0.44710 train_loss 1.82497
#     - test_acc  0.45080 test_loss  1.90697
# epoch 18
#     - train_acc 0.44710 train_loss 1.81512
#     - test_acc  0.45080 test_loss  1.84634
# epoch 19
#     - train_acc 0.44710 train_loss 1.90620
#     - test_acc  0.45080 test_loss  1.90143
# epoch 20
#     - train_acc 0.44710 train_loss 1.81703
#     - test_acc  0.45080 test_loss  1.87292
# epoch 21
#     - train_acc 0.44710 train_loss 1.80091
#     - test_acc  0.45080 test_loss  1.85533
# epoch 22
#     - train_acc 0.44710 train_loss 1.79134
#     - test_acc  0.45080 test_loss  1.83011
# epoch 23
#     - train_acc 0.44710 train_loss 1.80223
#     - test_acc  0.45080 test_loss  1.80480
# epoch 24
#     - train_acc 0.44710 train_loss 1.86804
#     - test_acc  0.45080 test_loss  1.78471
# epoch 25
#     - train_acc 0.44710 train_loss 1.82564
#     - test_acc  0.45080 test_loss  1.78386
# epoch 26
#     - train_acc 0.44710 train_loss 1.91063
#     - test_acc  0.45080 test_loss  1.82803
# epoch 27
#     - train_acc 0.44710 train_loss 1.87728
#     - test_acc  0.45080 test_loss  1.82202
# epoch 28
#     - train_acc 0.44710 train_loss 1.91438
#     - test_acc  0.45080 test_loss  1.90058
# epoch 29
#     - train_acc 0.44710 train_loss 1.89004
#     - test_acc  0.45080 test_loss  1.79327
# epoch 30
#     - train_acc 0.44710 train_loss 1.84856
#     - test_acc  0.45080 test_loss  1.78576
# epoch 31
#     - train_acc 0.44710 train_loss 1.80866
#     - test_acc  0.45080 test_loss  1.75174
# epoch 32
#     - train_acc 0.44710 train_loss 1.84864
#     - test_acc  0.45080 test_loss  1.81823
# epoch 33
#     - train_acc 0.44710 train_loss 1.86136
#     - test_acc  0.45080 test_loss  1.86483
# epoch 34
#     - train_acc 0.44710 train_loss 1.83100
#     - test_acc  0.45080 test_loss  1.83990
# epoch 35
#     - train_acc 0.44710 train_loss 1.82224
#     - test_acc  0.45080 test_loss  1.85042
# epoch 36
#     - train_acc 0.44710 train_loss 1.83606
#     - test_acc  0.45080 test_loss  1.78785
# epoch 37
#     - train_acc 0.44710 train_loss 1.87719
#     - test_acc  0.45080 test_loss  1.86315
# epoch 38
#     - train_acc 0.44710 train_loss 1.87712
#     - test_acc  0.45080 test_loss  1.85396
# epoch 39
#     - train_acc 0.44710 train_loss 1.87211
#     - test_acc  0.45080 test_loss  1.84380
# epoch 40
#     - train_acc 0.44710 train_loss 1.82175
#     - test_acc  0.45080 test_loss  1.78107
# epoch 41
#     - train_acc 0.44710 train_loss 1.81261
#     - test_acc  0.45080 test_loss  1.83847
# epoch 42
#     - train_acc 0.44710 train_loss 1.86623
#     - test_acc  0.45080 test_loss  1.82058
# epoch 43
#     - train_acc 0.44710 train_loss 1.84163
#     - test_acc  0.45080 test_loss  1.89778
# epoch 44
#     - train_acc 0.44710 train_loss 1.85233
#     - test_acc  0.45080 test_loss  1.94224
# epoch 45
#     - train_acc 0.44710 train_loss 1.84864
#     - test_acc  0.45080 test_loss  1.78271
# epoch 46
#     - train_acc 0.44710 train_loss 1.85855
#     - test_acc  0.45080 test_loss  1.90045
# epoch 47
#     - train_acc 0.44710 train_loss 1.79669
#     - test_acc  0.45080 test_loss  1.91279
# epoch 48
#     - train_acc 0.44710 train_loss 1.79551
#     - test_acc  0.45080 test_loss  1.88079
# epoch 49
#     - train_acc 0.44710 train_loss 1.74911
#     - test_acc  0.45080 test_loss  1.84860
# epoch 50
#     - train_acc 0.44710 train_loss 1.84432
#     - test_acc  0.45080 test_loss  1.88956
# epoch 51
#     - train_acc 0.44710 train_loss 1.78105
#     - test_acc  0.45080 test_loss  1.79110
# epoch 52
#     - train_acc 0.44710 train_loss 1.85093
#     - test_acc  0.45080 test_loss  1.78152
# epoch 53
#     - train_acc 0.44710 train_loss 1.84450
#     - test_acc  0.45080 test_loss  1.81558
# epoch 54
#     - train_acc 0.44710 train_loss 1.78505
#     - test_acc  0.45080 test_loss  1.72427
# epoch 55
#     - train_acc 0.44710 train_loss 1.86982
#     - test_acc  0.45080 test_loss  1.81068
# epoch 56
#     - train_acc 0.44710 train_loss 1.80507
#     - test_acc  0.45080 test_loss  1.94615
# epoch 57
#     - train_acc 0.44710 train_loss 1.81255
#     - test_acc  0.45080 test_loss  1.88679
# epoch 58
#     - train_acc 0.44710 train_loss 1.82168
#     - test_acc  0.45080 test_loss  1.84985
# epoch 59
#     - train_acc 0.44710 train_loss 1.80357
#     - test_acc  0.45080 test_loss  1.85498
# epoch 60
#     - train_acc 0.44710 train_loss 1.90754
#     - test_acc  0.45080 test_loss  1.82573
# epoch 61
#     - train_acc 0.44710 train_loss 1.80389
#     - test_acc  0.45080 test_loss  1.88552
# epoch 62
#     - train_acc 0.44710 train_loss 1.79593
#     - test_acc  0.45080 test_loss  1.85765
# epoch 63
#     - train_acc 0.44710 train_loss 1.82920
#     - test_acc  0.45080 test_loss  1.76166
# epoch 64
#     - train_acc 0.44710 train_loss 1.85474
#     - test_acc  0.45080 test_loss  1.82852
# epoch 65
#     - train_acc 0.44710 train_loss 1.87244
#     - test_acc  0.45080 test_loss  1.86319
# epoch 66
#     - train_acc 0.44710 train_loss 1.88275
#     - test_acc  0.45080 test_loss  1.94612
# epoch 67
#     - train_acc 0.44710 train_loss 1.81469
#     - test_acc  0.45080 test_loss  1.84043
# epoch 68
#     - train_acc 0.44710 train_loss 1.83449
#     - test_acc  0.45080 test_loss  1.81940
# epoch 69
#     - train_acc 0.44710 train_loss 1.86574
#     - test_acc  0.45080 test_loss  1.86331
# epoch 70
#     - train_acc 0.44710 train_loss 1.83279
#     - test_acc  0.45080 test_loss  1.86265
# epoch 71
#     - train_acc 0.44710 train_loss 1.82404
#     - test_acc  0.45080 test_loss  1.91813
# epoch 72
#     - train_acc 0.44710 train_loss 1.84029
#     - test_acc  0.45080 test_loss  1.84712
# epoch 73
#     - train_acc 0.44710 train_loss 1.79778
#     - test_acc  0.45080 test_loss  1.88081
# epoch 74
#     - train_acc 0.44710 train_loss 1.84691
#     - test_acc  0.45080 test_loss  1.83673
# epoch 75
#     - train_acc 0.44710 train_loss 1.80667
#     - test_acc  0.45080 test_loss  1.88372
# epoch 76
#     - train_acc 0.44710 train_loss 1.89023
#     - test_acc  0.45080 test_loss  1.83948
# epoch 77
#     - train_acc 0.44710 train_loss 1.78697
#     - test_acc  0.45080 test_loss  1.80465
# epoch 78
#     - train_acc 0.44710 train_loss 1.83236
#     - test_acc  0.45080 test_loss  1.81183
# epoch 79
#     - train_acc 0.44710 train_loss 1.89980
#     - test_acc  0.45080 test_loss  1.82144
# epoch 80
#     - train_acc 0.44710 train_loss 1.86368
#     - test_acc  0.45080 test_loss  1.77485
# epoch 81
#     - train_acc 0.44710 train_loss 1.79256
#     - test_acc  0.45080 test_loss  1.88859
# epoch 82
#     - train_acc 0.44710 train_loss 1.94360
#     - test_acc  0.45080 test_loss  1.78371
# epoch 83
#     - train_acc 0.44710 train_loss 1.77077
#     - test_acc  0.45080 test_loss  1.89131
# epoch 84
#     - train_acc 0.44710 train_loss 1.75041
#     - test_acc  0.45080 test_loss  1.85214
# epoch 85
#     - train_acc 0.44710 train_loss 1.83162
#     - test_acc  0.45080 test_loss  1.87583
# epoch 86
#     - train_acc 0.44710 train_loss 1.81990
#     - test_acc  0.45080 test_loss  1.84078
# epoch 87
#     - train_acc 0.44710 train_loss 1.83695
#     - test_acc  0.45080 test_loss  1.86448
# epoch 88
#     - train_acc 0.44710 train_loss 1.84337
#     - test_acc  0.45080 test_loss  1.76532
# epoch 89
#     - train_acc 0.44710 train_loss 1.74199
#     - test_acc  0.45080 test_loss  1.89301
# epoch 90
#     - train_acc 0.44710 train_loss 1.81454
#     - test_acc  0.45080 test_loss  1.78425
# epoch 91
#     - train_acc 0.44710 train_loss 1.84790
#     - test_acc  0.45080 test_loss  1.74351
# epoch 92
#     - train_acc 0.44710 train_loss 1.86644
#     - test_acc  0.45080 test_loss  1.84835
# epoch 93
#     - train_acc 0.44710 train_loss 1.82068
#     - test_acc  0.45080 test_loss  1.88471
# epoch 94
#     - train_acc 0.44710 train_loss 1.83884
#     - test_acc  0.45080 test_loss  1.86362
# epoch 95
#     - train_acc 0.44710 train_loss 1.84023
#     - test_acc  0.45080 test_loss  1.87398
# epoch 96
#     - train_acc 0.44710 train_loss 1.87904
#     - test_acc  0.45080 test_loss  1.86564
# epoch 97
#     - train_acc 0.44710 train_loss 1.81328
#     - test_acc  0.45080 test_loss  1.86544
# epoch 98
#     - train_acc 0.44710 train_loss 1.85035
#     - test_acc  0.45080 test_loss  1.85754
# epoch 99
#     - train_acc 0.44710 train_loss 1.84792
#     - test_acc  0.45080 test_loss  1.86921
# epoch 100
#     - train_acc 0.44710 train_loss 1.79576
#     - test_acc  0.45080 test_loss  1.91247
# {'Victim': 'vgg19_bn', 'Dataset': 'cifar_10', 'QueryType': 'coreset', 'QuerySize': 20000, 'Queried Output': 'Labels', 'Attacker': 'vgg19_bn', 'Train Loss': 1.7958, 'Train Accuracy': 44.71, 'Test Loss': 1.9125, 'Test Accuracy': 45.08}
# -----------------------------------------------------------------------------

# %%
Results
# Out:
# [{'Victim': 'vgg19_bn',
#   'Dataset': 'cifar_10',
#   'QueryType': 'coreset',
#   'QuerySize': 20000,
#   'Queried Output': 'Labels',
#   'Attacker': 'vgg19_bn',
#   'Train Loss': 1.7958,
#   'Train Accuracy': 44.71,
#   'Test Loss': 1.9125,
#   'Test Accuracy': 45.08}]
