# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/dl-model-extraction'

# %%
from attacker.training import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Case - 2

# %% [raw]
# Case 2 : Victim vs Attacker
#     Dataset - Cifar10
#     klogits - 0
#     QueryType - coreset
#     Query Size - 25k
#     Victim - R34, R50, VGG19
#     Attacker - R34, R50, VGG19

# %%
case2_v_resnet50 = {
        "query_size": [25000],
        "query_type": ['coreset'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
        "attacker":[RESNET50, VGG19_BN],
        "k_logits": [None]
}

# %% [markdown]
# # Investigations

# %% [markdown]
# ## case - 2

# %%
investigate(case2_v_resnet50, seed=37)
# Out:
# PARAMETERS for investigation:
# {'attacker': ['resnet50', 'vgg19_bn'],
#  'k_logits': [None],
#  'query_size': [25000],
#  'query_type': ['coreset'],
#  'victim': [{'data': 'cifar_10', 'model_name': 'resnet50'}]}
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:10000 queried:10000
# Sampling using None with query size 10000
# 	- input:10000 sampled:10000
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using coreset with query size 25000
# 	- input:50000 sampled:25000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet50
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 80/80 [33:18<00:00, 24.98s/it]
# {'Attacker': 'resnet50',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 51.29,
#  'Test Loss': 1.2988,
#  'Train Accuracy': 53.74,
#  'Train Loss': 1.212,
#  'Victim': 'resnet50'}
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: vgg19_bn
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 80/80 [1:05:59<00:00, 49.49s/it]
# {'Attacker': 'vgg19_bn',
#  'Dataset': 'cifar_10',
#  'Queried Logits': None,
#  'QuerySize': 25000,
#  'QueryType': 'coreset',
#  'Test Accuracy': 10.3,
#  'Test Loss': 2.3025,
#  'Train Accuracy': 10.05,
#  'Train Loss': 2.3026,
#  'Victim': 'resnet50'}
# -----------------------------------------------------------------------------
# [{'Attacker': 'resnet50',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 51.29,
#   'Test Loss': 1.2988,
#   'Train Accuracy': 53.74,
#   'Train Loss': 1.212,
#   'Victim': 'resnet50'},
#  {'Attacker': 'vgg19_bn',
#   'Dataset': 'cifar_10',
#   'Queried Logits': None,
#   'QuerySize': 25000,
#   'QueryType': 'coreset',
#   'Test Accuracy': 10.3,
#   'Test Loss': 2.3025,
#   'Train Accuracy': 10.05,
#   'Train Loss': 2.3026,
#   'Victim': 'resnet50'}]

# %% [raw]
# investigate(config["base"], seed=42) #to run default config
