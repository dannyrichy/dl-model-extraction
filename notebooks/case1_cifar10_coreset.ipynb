# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/home/richy/dl-model-extraction'

# %%
from attacker.training import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Case - 1

# %% [raw]
# Case 1: Corseset vs Random ,
#     Attacker - Resnet34
#     Victim - Resnet50
#     klogits - 0
#     Datasest - Cifar10, Cifar100
#     QueryType - Random, Coreset
#     Query Size - 5k, 10k, 25k, 50k

# %%
case1_cifar10 = {
        "query_size": [5000, 10000, 25000, 50000],
        "query_type": ['coreset','random'],
        "victim":[{ "data": CIFAR_10, "model_name": RESNET50}],
        "attacker":[RESNET34],
        "k_logits": [None]
}

# %% [markdown]
# # Investigations

# %% [markdown]
# ## case - 1 to 4

# %%
investigate(case1_cifar10, seed=42)
# Out:
# PARAMETERS for investigation:
# {'attacker': ['resnet34'],
#  'k_logits': [None],
#  'query_size': [5000, 10000, 25000, 50000],
#  'query_type': ['coreset', 'random'],
#  'victim': [{'data': 'cifar_10', 'model_name': 'resnet50'}]}
# ---------------------------------------------------------------------------
# Files already downloaded and verified
# Files already downloaded and verified
# Querying resnet50 victim on cifar_10 dataset
# 	- input:10000 queried:10000 -victim acc: 0.9364999532699585
# Sampling using None with query size 10000
# 	- input:10000 sampled:10000
# Querying resnet50 victim on cifar_10 dataset
# 	- input:50000 queried:50000 -victim acc: 0.9970600008964539
# Sampling using coreset with query size 5000
# 	- input:50000 sampled:5000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: coreset	Query Size: 5000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████| 600/600 [1:03:21<00:00,  6.34s/it]
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using coreset with query size 10000
# 	- input:50000 sampled:10000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: coreset	Query Size: 10000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 300/300 [50:20<00:00, 10.07s/it]
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using coreset with query size 25000
# 	- input:50000 sampled:25000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: coreset	Query Size: 25000	Logits: None
# -----------------------------------------------------------------------------
# 100%|█████████████████████████████████████████| 120/120 [42:22<00:00, 21.19s/it]
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using coreset with query size 50000
# 	- input:50000 sampled:50000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: coreset	Query Size: 50000	Logits: None
# -----------------------------------------------------------------------------
# 100%|███████████████████████████████████████████| 60/60 [39:53<00:00, 39.88s/it]
# -----------------------------------------------------------------------------
# Loading queried cifar_10 dataset with resnet50 victim
# 	- input:50000 queried:50000
# Sampling using random with query size 5000
# 	- input:50000 sampled:5000
#
# -----------------------------------------------------------------------------
# 	Dataset: cifar_10
# 	Victim: resnet50	Attacker: resnet34
# 	Query Type: random	Query Size: 5000	Logits: None
# -----------------------------------------------------------------------------
#   6%|██▎                                     | 34/600 [03:38<1:00:31,  6.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2182/3864788139.py in <module>
# ----> 1 investigate(case1_cifar10, seed=42)
#
# ~/dl-model-extraction/attacker/training.py in investigate(parameters, verbose, seed)
#     197                         # train attacker model
#     198                         attacker, attacker_result = attacker_training(attacker, querytrainloader, querytestloader,
# --> 199                                                             victim_type, outputs, k=k, verbose=verbose)
#     200
#     201
#
# ~/dl-model-extraction/attacker/training.py in attacker_training(attacker_model, trainloader, testloader, victim_type, num_classes, k, verbose)
#      83                 train_loss_func = loss(outputs, yList)
#      84                 train_loss_func.backward()
# ---> 85                 optimizer.step()
#      86                 scheduler.step()
#      87
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     151                    weight_decay=group['weight_decay'],
#     152                    eps=group['eps'],
# --> 153                    maximize=group['maximize'])
#     154         return loss
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#      95
#      96         # Decay the first and second moment running average coefficient
# ---> 97         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      98         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#      99         if amsgrad:
#
# KeyboardInterrupt:

# %% [raw]
# investigate(config["base"], seed=42) #to run default config
